# %%
import numpy as np # linear algebra
import pandas as pd

from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Embedding, LSTM, MaxPooling1D, Flatten, SpatialDropout1D, Conv1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.losses import CategoricalCrossentropy, BinaryCrossentropy
from tensorflow.keras.optimizers import SGD
import spacy
from tqdm.notebook import tqdm_notebook
from sklearn.model_selection import train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, accuracy_score, f1_score

from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
import re
spacy.require_gpu()
# Out:
# True

# %%
nlp = spacy.load('en_core_web_lg')

# %%
processed_directory = '../processed_data/'
train_df = pd.read_json('../processed_data/train.json')
test_df = pd.read_json('../processed_data/test.json')

# %%
train_df
# Out:
#           id                                               text  rating label
# 0          0  Bromwell High is a cartoon comedy. It ran at t...       9     +
# 1      10000  Homelessness (or Houselessness as George Carli...       8     +
# 2      10001  Brilliant over-acting by Lesley Ann Warren. Be...      10     +
# 3      10002  This is easily the most underrated film inn th...       7     +
# 4      10003  This is not the typical Mel Brooks film. It wa...       8     +
# ...      ...                                                ...     ...   ...
# 24995   9998  Towards the end of the movie, I felt it was to...       4     -
# 24996   9999  This is the kind of movie that my enemies cont...       3     -
# 24997    999  I saw 'Descent' last night at the Stockholm Fi...       3     -
# 24998     99  Some films that you pick up for a pound turn o...       1     -
# 24999      9  This is one of the dumbest films, I've ever se...       1     -
#
# [25000 rows x 4 columns]

# %%
def clean_text(df):
    text_list = df['text'].to_list()
    x = []
    for doc in tqdm_notebook(nlp.pipe(text_list, disable=["parser", "lemmatizer", 'ner']),total=len(text_list) ):
        output = [token.text for token in doc if not (token.is_stop or token.pos_ == 'PUNCT')]
        x.append(' '.join(output))
    df['text'] = pd.Series(x)

def get_features(df, tokenizer):
    x = tokenizer.texts_to_sequences(df['text'].values)
    x = pad_sequences(x)
    y = df['label']
    y = pd.get_dummies(y)
    return x, y

# %%
clean_text(train_df)
clean_text(test_df)
# Out:
#   0%|          | 0/25000 [00:00<?, ?it/s]
#   0%|          | 0/25000 [00:00<?, ?it/s]

# %%
train_df
# Out:
#           id                                               text  rating label
# 0          0  Bromwell High cartoon comedy ran time programs...       9     +
# 1      10000  Homelessness Houselessness George Carlin state...       8     +
# 2      10001  Brilliant acting Lesley Ann Warren Best dramat...      10     +
# 3      10002  easily underrated film inn Brooks cannon Sure ...       7     +
# 4      10003  typical Mel Brooks film slapstick movies actua...       8     +
# ...      ...                                                ...     ...   ...
# 24995   9998  end movie felt technical felt like classroom w...       4     -
# 24996   9999  kind movie enemies content watch time bloody t...       3     -
# 24997    999  saw Descent night Stockholm Film Festival huge...       3     -
# 24998     99  films pick pound turn good 23rd Century films ...       1     -
# 24999      9  dumbest films seen rips nearly type thriller m...       1     -
#
# [25000 rows x 4 columns]

# %%
max_features = 1000
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(train_df['text'].values)

# %%
train_x, train_y = get_features(train_df, tokenizer)
test_x, test_y = get_features(test_df, tokenizer)

# %%
train_x.shape
# Out:
# (25000, 442)

# %%
embed_dim = 128
lstm_out = 196

model = Sequential()
model.add(Embedding(max_features, embed_dim,input_length = train_x.shape[1]))
model.add(Conv1D(filters=32, kernel_size=8, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(30, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(30, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(30, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(2,activation='sigmoid'))
model.summary()

callbacks=[
    ModelCheckpoint(filepath='./models_lstm/checkpoint',
                   save_best_only=True, verbose=1)
]
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 442, 128)          128000
#
#  conv1d_2 (Conv1D)           (None, 435, 32)           32800
#
#  max_pooling1d_2 (MaxPooling  (None, 217, 32)          0
#  1D)
#
#  flatten_2 (Flatten)         (None, 6944)              0
#
#  dropout (Dropout)           (None, 6944)              0
#
#  dense_5 (Dense)             (None, 30)                208350
#
#  dropout_1 (Dropout)         (None, 30)                0
#
#  dense_6 (Dense)             (None, 30)                930
#
#  dropout_2 (Dropout)         (None, 30)                0
#
#  dense_7 (Dense)             (None, 30)                930
#
#  dropout_3 (Dropout)         (None, 30)                0
#
#  dense_8 (Dense)             (None, 2)                 62
#
# =================================================================
# Total params: 371,072
# Trainable params: 371,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=BinaryCrossentropy(), optimizer=SGD(momentum=0.02))
model.fit(x=train_x,
         y=train_y,
         batch_size=256,
         epochs=50,
         validation_split=0.3,
         callbacks=callbacks)
# Out:
# Epoch 1/50
# 69/69 [==============================] - ETA: 0s - loss: 0.6795
# Epoch 1: val_loss improved from inf to 0.77556, saving model to ./models_lstm\checkpoint
# INFO:tensorflow:Assets written to: ./models_lstm\checkpoint\assets
# 69/69 [==============================] - 2s 24ms/step - loss: 0.6795 - val_loss: 0.7756
# Epoch 2/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6543
# Epoch 2: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6541 - val_loss: 0.8648
# Epoch 3/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6353
# Epoch 3: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6351 - val_loss: 0.9626
# Epoch 4/50
# 68/69 [============================>.] - ETA: 0s - loss: 0.6212
# Epoch 4: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6212 - val_loss: 1.0554
# Epoch 5/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6156
# Epoch 5: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6156 - val_loss: 1.1106
# Epoch 6/50
# 68/69 [============================>.] - ETA: 0s - loss: 0.6113
# Epoch 6: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6114 - val_loss: 1.1445
# Epoch 7/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6086
# Epoch 7: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6080 - val_loss: 1.1755
# Epoch 8/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6075
# Epoch 8: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6072 - val_loss: 1.1820
# Epoch 9/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6063
# Epoch 9: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6064 - val_loss: 1.1795
# Epoch 10/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6058
# Epoch 10: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6059 - val_loss: 1.1738
# Epoch 11/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6042
# Epoch 11: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6049 - val_loss: 1.1863
# Epoch 12/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6055
# Epoch 12: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6062 - val_loss: 1.1797
# Epoch 13/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6041
# Epoch 13: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6043 - val_loss: 1.1867
# Epoch 14/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6023
# Epoch 14: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6026 - val_loss: 1.2002
# Epoch 15/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6026
# Epoch 15: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6025 - val_loss: 1.1996
# Epoch 16/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6019
# Epoch 16: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6020 - val_loss: 1.2017
# Epoch 17/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6031
# Epoch 17: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6031 - val_loss: 1.1956
# Epoch 18/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6035
# Epoch 18: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6028 - val_loss: 1.1952
# Epoch 19/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6032
# Epoch 19: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6026 - val_loss: 1.2001
# Epoch 20/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6017
# Epoch 20: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6015 - val_loss: 1.2076
# Epoch 21/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6009
# Epoch 21: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6010 - val_loss: 1.2037
# Epoch 22/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6013
# Epoch 22: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6019 - val_loss: 1.2031
# Epoch 23/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6021
# Epoch 23: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6019 - val_loss: 1.2023
# Epoch 24/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6025
# Epoch 24: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6015 - val_loss: 1.2082
# Epoch 25/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6014
# Epoch 25: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6013 - val_loss: 1.2077
# Epoch 26/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6018
# Epoch 26: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6016 - val_loss: 1.2045
# Epoch 27/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6017
# Epoch 27: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6012 - val_loss: 1.2136
# Epoch 28/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5998
# Epoch 28: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6002 - val_loss: 1.2151
# Epoch 29/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5999
# Epoch 29: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6007 - val_loss: 1.2156
# Epoch 30/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6008
# Epoch 30: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6011 - val_loss: 1.2102
# Epoch 31/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6009
# Epoch 31: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6007 - val_loss: 1.2149
# Epoch 32/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6016
# Epoch 32: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6011 - val_loss: 1.2151
# Epoch 33/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6002
# Epoch 33: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6003 - val_loss: 1.2165
# Epoch 34/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6000
# Epoch 34: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6001 - val_loss: 1.2181
# Epoch 35/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6008
# Epoch 35: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6006 - val_loss: 1.2142
# Epoch 36/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6003
# Epoch 36: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6006 - val_loss: 1.2149
# Epoch 37/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5995
# Epoch 37: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5996 - val_loss: 1.2221
# Epoch 38/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6000
# Epoch 38: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5996 - val_loss: 1.2266
# Epoch 39/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5992
# Epoch 39: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5994 - val_loss: 1.2285
# Epoch 40/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5988
# Epoch 40: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5990 - val_loss: 1.2270
# Epoch 41/50
# 68/69 [============================>.] - ETA: 0s - loss: 0.5996
# Epoch 41: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5996 - val_loss: 1.2280
# Epoch 42/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6005
# Epoch 42: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.6001 - val_loss: 1.2248
# Epoch 43/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5997
# Epoch 43: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5998 - val_loss: 1.2260
# Epoch 44/50
# 69/69 [==============================] - ETA: 0s - loss: 0.5998
# Epoch 44: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5998 - val_loss: 1.2257
# Epoch 45/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5984
# Epoch 45: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5990 - val_loss: 1.2286
# Epoch 46/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.6004
# Epoch 46: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5998 - val_loss: 1.2346
# Epoch 47/50
# 68/69 [============================>.] - ETA: 0s - loss: 0.5996
# Epoch 47: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5994 - val_loss: 1.2285
# Epoch 48/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5992
# Epoch 48: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5990 - val_loss: 1.2319
# Epoch 49/50
# 67/69 [============================>.] - ETA: 0s - loss: 0.5989
# Epoch 49: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5992 - val_loss: 1.2286
# Epoch 50/50
# 68/69 [============================>.] - ETA: 0s - loss: 0.5995
# Epoch 50: val_loss did not improve from 0.77556
# 69/69 [==============================] - 1s 10ms/step - loss: 0.5996 - val_loss: 1.2275
